# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Machine_Learning/blob/main/API_key_form.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
from google.colab import userdata

# Get the API key securely from Colab's secrets manager
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=OPENAI_API_KEY)
response = client.responses.create(
    model='gpt-3.5-turbo',
    input = "Ali 25 yoshda.Menga output format json ma'lumotlar chiqar databaseni to'ldirish uchun"
)

# %%
print(response.output[0].content[0].text)
# Out:
# ```json
# [
#   {
#     "Ism": "Ali",
#     "Yosh": 25
#   }
# ]
# ```

# %%
response = client.responses.create(
    model = 'gpt-3.5-turbo',
    input = "Ertaga soar 5 da meeting bor. Out put format faqat json format bo'lsin kerkali ma'lumotlarni ol ortiqcha text ma'lumot yozma faqat json kerak. 'task', 'time', 'date'"
)
print(response.output[0].content[0].text)
# Out:
# {
# 	"task": "Meeting",
# 	"time": "5:00 PM",
# 	"date": "Tomorrow"
# }

# %%
response = client.responses.create(
    model = 'gpt-3.5-turbo',
    input = "To'lov qildim premium ochilmadi. Output format faqat va faqt json. 'category', 'priority','sentiment'"
)
print(response.output[0].content[0].text)
# Out:
# {
#     "category": "Payment",
#     "priority": "High",
#     "sentiment": "Neutral"
# }

# %%
response = client.responses.create(
    model = 'gpt-5.4',
    input = "Ali mathdan 87, physicsdan 91 oldi. Menga db uchun to'liq ma'lumot only json dict bo'lsin."
)
print(response.output[0].content[0].text)
# Out:
# {"name":"Ali","grades":{"math":87,"physics":91}}

# %%
response = client.responses.create(
    model = 'gpt-5.4',
    input = "Learn LangChain in 30 Minutes | Beginner Tutorial. Only json form user information ."
)
print(response.output[0].content[0].text)
# Out:
# {
#   "title": "Learn LangChain in 30 Minutes | Beginner Tutorial",
#   "user_information": {
#     "skill_level": "beginner",
#     "topic": "LangChain",
#     "learning_goal": "learn LangChain in 30 minutes",
#     "preferred_format": "tutorial",
#     "time_available": "30 minutes"
#   }
# }

# %%
response = client.responses.create(
    model = 'gpt-5.4',
    input = "2 ta iPhone 15 Pro va 1 ta AirPods Pro olmoqchiman. Shop ma'lumot faqat json formatda"
)
print(response.output[0].content[0].text)
# Out:
# {"products":[{"name":"iPhone 15 Pro","quantity":2},{"name":"AirPods Pro","quantity":1}],"note":"Siz 2 ta iPhone 15 Pro va 1 ta AirPods Pro olmoqchisiz."}
