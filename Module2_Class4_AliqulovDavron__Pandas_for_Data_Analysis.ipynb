# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Machine_Learning/blob/main/Module2_Class4_AliqulovDavron__Pandas_for_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Series and DataFrames (maps to lecture section “Series and DataFrames”)

# %%
import pandas as pd #Upload pandas for data preparation
import seaborn as sns #Upload seaborn for data visualization and tips dataset
import numpy as np #Upload numpy for data preparation

# %%
df = pd.DataFrame({
"name": ["Ali", "Zara", "Jasur"],
"age": [22, 28, 31],
"city": ["Tashkent", "Samarkand", "Bukhara"]
}) #Data frame

# %% [markdown]
# Series age column

# %%
df["age"] # Age column
# Out:
# 0    22
# 1    28
# 2    31
# Name: age, dtype: int64

# %%
df[["name", "age"]] # Name and Age columns
# Out:
#     name  age
# 0    Ali   22
# 1   Zara   28
# 2  Jasur   31

# %%
print(df.index) # Show index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# Add three more rows to df

# %%
new_data = pd.DataFrame({
    "name": ["Omar", "Sofia", "David"],
    "age": [25, 30, 29],
    "city": ["Almaty", "Kyiv", "Berlin"]
})
# new dataframe
df = pd.concat([df, new_data], ignore_index=True) # add data ignore index
display(df)
# Out:
#     name  age       city
# 0    Ali   22   Tashkent
# 1   Zara   28  Samarkand
# 2  Jasur   31    Bukhara
# 3   Omar   25     Almaty
# 4  Sofia   30       Kyiv
# 5  David   29     Berlin

# %% [markdown]
# # Loading and Exploring (maps to lecture section “Loading and Exploring”)

# %%
tips_df = sns.load_dataset('tips')
print("Built-in 'tips' dataset head:")
tips_df = pd.DataFrame(tips_df)
print("Tips DataFrame head:")
display(tips_df)
# Out:
# Built-in 'tips' dataset head:
# Tips DataFrame head:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df['time']
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
tips_df.head(5) #Tipss dataset all column and 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.shape #Dataset shape col x row
# Out:
# (244, 7)

# %%
tips_df.info() # Column elements, column name, types, there are null elemens , dimension type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips_df.describe() #Dataframe numbers element coun, mean, std, min, iqr, max
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_df.isna().sum() #Data null elements summa each columns
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Filtering, GroupBy, Merging (maps to lecture section “Filtering, GroupBy, Merging”)

# %% [markdown]
# ## Boolean filtering

# %%
tips_df[(tips_df['total_bill'] >=20) & (tips_df['sex'] == 'Male')] # Short command and fast read  use &, parentheses not to avoid confusion
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# 15        21.58  3.92  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 227       20.45  3.00  Male     No  Sat  Dinner     4
# 230       24.01  2.00  Male    Yes  Sat  Dinner     4
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
#
# [70 rows x 7 columns]

# %% [markdown]
# ## GroupBy: split-apply-combine

# %%
tips_df.groupby('sex')['total_bill'].mean() #Group gender men total bill
# Out:
# /tmp/ipykernel_14074/3812446729.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('sex')['total_bill'].mean() #Group gender men total bill
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
tips_df.groupby('sex')['smoker'].count() # Gender smoker count
# Out:
# /tmp/ipykernel_14074/3372964764.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('sex')['smoker'].count() # Gender smoker count
# sex
# Male      157
# Female     87
# Name: smoker, dtype: int64

# %%
tips_df.groupby('sex').agg({'total_bill': ['mean', 'min', 'max'], 'tip': ['mean', 'min','max'], 'size': ['mean', 'min', 'max'], 'smoker': 'count'}) # Describe gender elements
# Out:
# /tmp/ipykernel_14074/2713482208.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('sex').agg({'total_bill': ['mean', 'min', 'max'], 'tip': ['mean', 'min','max'], 'size': ['mean', 'min', 'max'], 'smoker': 'count'}) # Describe gender elements
#        total_bill                    tip                 size         smoker
#              mean   min    max      mean  min   max      mean min max  count
# sex
# Male    20.744076  7.25  50.81  3.089618  1.0  10.0  2.630573   1   6    157
# Female  18.056897  3.07  44.30  2.833448  1.0   6.5  2.459770   1   6     87

# %% [markdown]
# ##Merging

# %%
day_type_lookup = pd.DataFrame({
    'day': ['Thur', 'Fri', 'Sat', 'Sun'],
    'day_type': ['Weekday', 'Weekday', 'Weekend', 'Weekend']
})

print("Lookup DataFrame:")
display(day_type_lookup)
# Out:
# Lookup DataFrame:
#     day day_type
# 0  Thur  Weekday
# 1   Fri  Weekday
# 2   Sat  Weekend
# 3   Sun  Weekend

# %%
tips_df_merged = pd.merge(tips_df, day_type_lookup, on='day', how='left')

print("Merged DataFrame (first 5 rows with new 'day_type' column):")
display(tips_df_merged.head())
# Out:
# Merged DataFrame (first 5 rows with new 'day_type' column):
#    total_bill   tip     sex smoker  day    time  size day_type
# 0       16.99  1.01  Female     No  Sun  Dinner     2  Weekend
# 1       10.34  1.66    Male     No  Sun  Dinner     3  Weekend
# 2       21.01  3.50    Male     No  Sun  Dinner     3  Weekend
# 3       23.68  3.31    Male     No  Sun  Dinner     2  Weekend
# 4       24.59  3.61  Female     No  Sun  Dinner     4  Weekend

# %%
region_names = ['west', 'south', 'north', 'east']

# Create a Series of regions with the same length as tips_df
# This will be used to add a 'region' column to tips_df
tips_df_regions = pd.Series(np.random.choice(region_names, size=len(tips_df)))

# %%
# Create a copy of tips_df to add the new 'region' column
tips_df_with_regions = tips_df.copy()
tips_df_with_regions['region'] = tips_df_regions

print("DataFrame with 'region' column (first 5 rows):")
display(tips_df_with_regions.head())
# Out:
# DataFrame with 'region' column (first 5 rows):
#    total_bill   tip     sex smoker  day    time  size region
# 0       16.99  1.01  Female     No  Sun  Dinner     2  north
# 1       10.34  1.66    Male     No  Sun  Dinner     3   west
# 2       21.01  3.50    Male     No  Sun  Dinner     3   west
# 3       23.68  3.31    Male     No  Sun  Dinner     2  north
# 4       24.59  3.61  Female     No  Sun  Dinner     4   east
